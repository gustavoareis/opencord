# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoareis/discord-bot/blob/main/youtube_Po_Token_download_ffmpeg_merge_AV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !npm install -g youtube-po-token-generator

# %%
# !pip install pytubefix

# %%
# !apt install ffmpeg

# %%
# !youtube-po-token-generator
# Out:
# <--- Last few GCs --->
#
# [9152:0x1f0b6bd0]   131520 ms: Scavenge (reduce) 2037.4 (2082.8) -> 2037.3 (2082.8) MB, 19.48 / 0.01 ms  (average mu = 0.424, current mu = 0.415) allocation failure;
# [9152:0x1f0b6bd0]   136859 ms: Mark-Compact (reduce) 2040.8 (2086.2) -> 2029.6 (2086.2) MB, 4874.06 / 0.12 ms  (+ 14.6 ms in 4 steps since start of marking, biggest step 3.8 ms, walltime since start of marking 4964 ms) (average mu = 0.328, current mu = 0.
#
# <--- JS stacktrace --->
#
# FATAL ERROR: Reached heap limit Allocation failed - JavaScript heap out of memory
# ----- Native stack trace -----
#
#  1: 0xb8cf03 node::OOMErrorHandler(char const*, v8::OOMDetails const&) [node]
#  2: 0xf04140 v8::Utils::ReportOOMFailure(v8::internal::Isolate*, char const*, v8::OOMDetails const&) [node]
#  3: 0xf04427 v8::internal::V8::FatalProcessOutOfMemory(v8::internal::Isolate*, char const*, v8::OOMDetails const&) [node]
#  4: 0x1116075  [node]
# ...

# %%
from pytubefix import YouTube
from pytubefix.cli import on_progress

url = "https://youtu.be/l54a1O53ZiA?list=RDlzG91CHPz-A"

yt = YouTube(url, use_po_token=True)
print(yt.title)

for i, l in enumerate(yt.streams):
    print(i, l)

print("\nDone")
# Out:
# WARNING:pytubefix.__main__:`use_po_token` and `po_token_verifier` is deprecated and will be removed soon.
# You can use the tool: https://github.com/YunzheZJU/youtube-po-token-generator, to get the token
# Enter with your visitorData: Cgt1Sk5zaXNQdUpEMCjDrKDOBjIKCgJVUxIEGgAgDg%3D%3D
# Enter with your po_token: Mni5G98UubFoKrkn1fMHanqdkx1LIiDEDzjwc60I8cIowYq0copNzLH-nzPUQQlOHCh-w5F9HITJappq_6LT_DIOdhi_Z-KaaTnjgqYvY_-6PFUaBOdoxNk8ebXfyumk3cbIhLQwAIs7_o3kDrgC2rXOkWCFj0K9W94=
# VEIGH - Londres Freestyle 🇬🇧 Prod. Nagalli & Viper (Clipe Oficial)
# 0 <Stream: itag="18" mime_type="video/mp4" res="360p" fps="24fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" sabr="False" type="video">
# 1 <Stream: itag="313" mime_type="video/webm" res="2160p" fps="24fps" vcodec="vp9" progressive="False" sabr="False" type="video">
# 2 <Stream: itag="401" mime_type="video/mp4" res="2160p" fps="24fps" vcodec="av01.0.12M.08" progressive="False" sabr="False" type="video">
# ...

# %%
yt.streams[1].download()
yt.streams[16].download()

# %%
# !ffmpeg -i "video_file" -i "sound_file" -c:v copy -c:a aac "output_file.mp4"
